# %%
import eyed3
import os

class MP3TagEditor:
    def __init__(self, file_path):
        self.file_path = file_path
        print(file_path)
        try:
            self.audiofile = eyed3.load(file_path)  # Try to load the MP3 file
            if self.audiofile is None:
                raise ValueError(f"Failed to load the MP3 file: {file_path}")

            # Initialize tags if they are missing
            if self.audiofile.tag is None:
                print(f"No tags found for {self.file_path}. Initializing tags.")
                self.audiofile.tag = eyed3.id3.tag.Tag()  # Initialize an empty tag object
                # Set default tags
                self.audiofile.tag.artist = "Unknown Artist"
                self.audiofile.tag.album = "Unknown Album"
                self.audiofile.tag.title = "Unknown Title"
                self.audiofile.tag.year = 2023  # You can set the current year or a default one
                self.audiofile.tag.genre = "Unknown Genre"
                self.audiofile.tag.save()  # Save the initialized tags
                print("Tags initialized and saved.")
        except Exception as e:
            print(f"Failed to open {file_path}: {e}")
            self.audiofile = None  # Set to None to indicate failure

    def display_tags(self):
        """Display the current tags of the MP3 file"""
        if self.audiofile is None or self.audiofile.tag is None:
            print(f"No tags found for {self.file_path}.")
            return
            
        print(f"Title: {self.audiofile.tag.title}")
        print(f"Artist: {self.audiofile.tag.artist}")
        print(f"Album: {self.audiofile.tag.album}")
        #print(f"Year: {self.audiofile.tag.year}")
        print(f"Genre: {self.audiofile.tag.genre}")

    def edit_tag(self, title=None, artist=None, album=None, year=None, genre=None):
        """Edit the tags of the MP3 file"""
        if self.audiofile and self.audiofile.tag:
            if title:
                self.audiofile.tag.title = title
            if artist:
                self.audiofile.tag.artist = artist
            if album:
                self.audiofile.tag.album = album
            if year:
                self.audiofile.tag.year = year
            if genre:
                self.audiofile.tag.genre = genre

    def save(self):
        """Save the changes to the MP3 file"""
        if self.audiofile and self.audiofile.tag:
            self.audiofile.tag.save()


def process_directory(directory_path, title=None, artist=None, album=None, year=None, genre=None):
    """Process all MP3 files in a directory"""
    for filename in os.listdir(directory_path):
        if filename.endswith(".mp3"):
            file_path = os.path.join(directory_path, filename)
            print(f"Processing: {file_path}")
            mp3_editor = MP3TagEditor(file_path)
            
            # Skip if the file couldn't be loaded
            if mp3_editor.audiofile is None:
                print(f"Skipping {file_path} due to loading failure.")
                continue  # Skip to the next file
            
            # Display current tags
            print("Current MP3 Tags:")
            #mp3_editor.display_tags()

            # Edit tags
            print("\nUpdating MP3 Tags...")
            mp3_editor.edit_tag(title, artist, album, year, genre)
            
            mp3_editor.save()
            
            # Display updated tags
            print("\nUpdated MP3 Tags:")
            mp3_editor.display_tags()
            print("-" * 50)

if __name__ == "__main__":
    directory_path = r"C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads"

    # Pass the values to be updated or leave them as None to keep existing ones
    process_directory(directory_path, album="Pre22March2025")
# Out:
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\24kGoldn - CITY OF ANGELS (Official Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\24kGoldn - CITY OF ANGELS (Official Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\3 Doors Down - Here Without You (Official Music Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\3 Doors Down - Here Without You (Official Music Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\3 Doors Down - When I'm Gone (Official Music Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\3 Doors Down - When I'm Gone (Official Music Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\3DG - (I Hate) Everything About You lyrics [Uncensored].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\3DG - (I Hate) Everything About You lyrics [Uncensored].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\5 Seconds of Summer - Old Me (Official Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\5 Seconds of Summer - Old Me (Official Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Abba - Fernando.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Abba - Fernando.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Adelitas Way - Closer to You.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Adelitas Way - Closer to You.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Adelitas Way - Crush.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Adelitas Way - Crush.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Adelitas Way - Invincible(lyrics) HQ.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Adelitas Way - Invincible(lyrics) HQ.mp3
# Failed to open C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Adelitas Way - Invincible(lyrics) HQ.mp3: Failed to load the MP3 file: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Adelitas Way - Invincible(lyrics) HQ.mp3
# Skipping C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Adelitas Way - Invincible(lyrics) HQ.mp3 due to loading failure.
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Alamo [Official Lyric Video].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Alamo [Official Lyric Video].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - At the Bottom (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - At the Bottom (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Beautiful Pain (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Beautiful Pain (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Demons (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Demons (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Gabriel (MUSIC VIDEO).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Gabriel (MUSIC VIDEO).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Gotta Be A Reason [Official Lyric Video].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Gotta Be A Reason [Official Lyric Video].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - If I Killed Someone For You [Official Lyric Video].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - If I Killed Someone For You [Official Lyric Video].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - If We Have Each Other [Official Music Video].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - If We Have Each Other [Official Music Video].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Jesus In LA (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Jesus In LA (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Just Like You [Official Lyric Video].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Just Like You [Official Lyric Video].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Let Me Down Slowly [Official Music Video].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Let Me Down Slowly [Official Music Video].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Lock me up for Life (QUARANTINE DEMO).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Lock me up for Life (QUARANTINE DEMO).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Match In The Rain [Official Music Video].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Match In The Rain [Official Music Video].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Mind Is A Prison [Official Lyric Video].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Mind Is A Prison [Official Lyric Video].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Must Have Been The Wind (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Must Have Been The Wind (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Oh My God (Bedroom Session).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Oh My God (Bedroom Session).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Older (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Older (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Settle Down.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Settle Down.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Six Feet Apart [Official Lyric Video].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - Six Feet Apart [Official Lyric Video].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - The Book Of You & I [Official Lyric Video].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - The Book Of You & I [Official Lyric Video].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - The Hill I Will Die On (Demo).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin - The Hill I Will Die On (Demo).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\alec benjamin - use melyrics.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\alec benjamin - use melyrics.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin Water Fountain (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Alec Benjamin Water Fountain (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ali Gatie - It's You (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ali Gatie - It's You (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\alt-J () Breezeblocks.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\alt-J () Breezeblocks.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ane Brun - Halo.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ane Brun - Halo.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Atreyu - GodDevil.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Atreyu - GodDevil.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Austin Mahone - All I Ever Need (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Austin Mahone - All I Ever Need (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Avicii - Hey Brother.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Avicii - Hey Brother.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Avicii - Wake Me Up (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Avicii - Wake Me Up (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Backstreet Boys - I want it that way (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Backstreet Boys - I want it that way (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Backstreet boys everybody lyrics.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Backstreet boys everybody lyrics.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bastille - Good Grief (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bastille - Good Grief (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bastille - Million Pieces ft. The Chamber Orchestra Of London.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bastille - Million Pieces ft. The Chamber Orchestra Of London.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bastille - Oblivion (Official Music Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bastille - Oblivion (Official Music Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bastille - Pompeii (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bastille - Pompeii (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bastille - Those Nights.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bastille - Those Nights.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Before I Forget.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Before I Forget.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ben Platt - In Case You Don't Live Forever (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ben Platt - In Case You Don't Live Forever (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Big & Rich - Save A Horse [Ride A Cowboy] (Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Big & Rich - Save A Horse [Ride A Cowboy] (Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Big Mountain - Baby I Love Your Way Lyrics.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Big Mountain - Baby I Love Your Way Lyrics.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Big Sean - Wolves ft. Post Malone.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Big Sean - Wolves ft. Post Malone.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Billy Idol - Dancing With Myself (Official Music Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Billy Idol - Dancing With Myself (Official Music Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Billy Joel - Uptown Girl (Official Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Billy Joel - Uptown Girl (Official Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Billy Lockett - Call Me In The Morning (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Billy Lockett - Call Me In The Morning (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Billy Talent - The Crutch - LYRICS.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Billy Talent - The Crutch - LYRICS.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\blackbear - idfc (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\blackbear - idfc (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Blake Shelton - Nobody But You (Duet with Gwen Stefani) (Official Music Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Blake Shelton - Nobody But You (Duet with Gwen Stefani) (Official Music Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bon Jovi - Its my life w lyrics.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bon Jovi - Its my life w lyrics.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bon Jovi - Wanted Dead Or Alive (Official Music Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bon Jovi - Wanted Dead Or Alive (Official Music Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bon Jovi - You give love a bad name - lyrics.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bon Jovi - You give love a bad name - lyrics.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Boston - Peace of Mind (Audio).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Boston - Peace of Mind (Audio).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - Angels Fall (Official Video)(1).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - Angels Fall (Official Video)(1).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - Breath - Lyrics Video.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - Breath - Lyrics Video.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
# Non standard genre name: Unknown Genre
# Non standard genre name: Unknown Genre
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - Dance with the devil lyrics.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - Dance with the devil lyrics.mp3
# No tags found for C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - Dance with the devil lyrics.mp3. Initializing tags.
# Tags initialized and saved.
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: Unknown Title
# Artist: Unknown Artist
# Album: Pre22March2025
# Genre: Unknown Genre
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - I Will Not Bow (Official Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - I Will Not Bow (Official Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
# Non standard genre name: Unknown Genre
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - So Cold.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - So Cold.mp3
# Failed to open C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - So Cold.mp3: Failed to load the MP3 file: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - So Cold.mp3
# Skipping C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - So Cold.mp3 due to loading failure.
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - The Diary of Jane (Official Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - The Diary of Jane (Official Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - Topless.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - Topless.mp3
# No tags found for C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Breaking Benjamin - Topless.mp3. Initializing tags.
# Non standard genre name: Unknown Genre
# Tags initialized and saved.
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: Unknown Title
# Artist: Unknown Artist
# Album: Pre22March2025
# Genre: Unknown Genre
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Brighter Than Gold - Louis II (LYRICS).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Brighter Than Gold - Louis II (LYRICS).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bring Me The Horizon - sTraNgeRs (Official Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bring Me The Horizon - sTraNgeRs (Official Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bruno Mars - It Will Rain - Lyrics.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bruno Mars - It Will Rain - Lyrics.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bruno Mars - The Lazy Song [OFFICIAL VIDEO].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bruno Mars - The Lazy Song [OFFICIAL VIDEO].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bullet For My Valentine - Tears Don't Fall (Album Edit - with Scream with Lighter).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bullet For My Valentine - Tears Don't Fall (Album Edit - with Scream with Lighter).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bullet For My Valentine - Tears Don't Fall (Official Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Bullet For My Valentine - Tears Don't Fall (Official Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Calvin Harris - Summer (Audio).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Calvin Harris - Summer (Audio).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Carly Simon - You're So Vain.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Carly Simon - You're So Vain.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Carol of the Bells - Trans-Siberian Orchestra - Higher Quality.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Carol of the Bells - Trans-Siberian Orchestra - Higher Quality.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Cats In the Cradle- Harry Chapin Lyrics.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Cats In the Cradle- Harry Chapin Lyrics.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Centuries - Fall Out Boy (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Centuries - Fall Out Boy (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Charlie Puth - How Long (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Charlie Puth - How Long (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Chilliwack (Fly At Night)...1977...Lyrics Provided Under Info.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Chilliwack (Fly At Night)...1977...Lyrics Provided Under Info.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\CHOKE.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\CHOKE.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Chosen One - Valley of Wolves (LYRICS).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Chosen One - Valley of Wolves (LYRICS).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Chris Brown - Forever (Official Music Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Chris Brown - Forever (Official Music Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Chris Janson - Drunk Girl(Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Chris Janson - Drunk Girl(Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Christina Aguilera - Fighter (Official Music Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Christina Aguilera - Fighter (Official Music Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Christina Perri - A Thousand Years [Official Music Video].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Christina Perri - A Thousand Years [Official Music Video].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Coheed and Cambria - Shoulders [Official Lyric Video].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Coheed and Cambria - Shoulders [Official Lyric Video].mp3
# Failed to open C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Coheed and Cambria - Shoulders [Official Lyric Video].mp3: Failed to load the MP3 file: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Coheed and Cambria - Shoulders [Official Lyric Video].mp3
# Skipping C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Coheed and Cambria - Shoulders [Official Lyric Video].mp3 due to loading failure.
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Coheed and Cambria - Welcome Home (Official Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Coheed and Cambria - Welcome Home (Official Video).mp3
# Failed to open C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Coheed and Cambria - Welcome Home (Official Video).mp3: Failed to load the MP3 file: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Coheed and Cambria - Welcome Home (Official Video).mp3
# Skipping C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Coheed and Cambria - Welcome Home (Official Video).mp3 due to loading failure.
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\College Football Pump Up Seven Nation Army 2017-2018 ᴴᴰ.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\College Football Pump Up Seven Nation Army 2017-2018 ᴴᴰ.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Comatose.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Comatose.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Come and get Your Love(Guardians of the Galaxy Intro song) - Redbone.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Come and get Your Love(Guardians of the Galaxy Intro song) - Redbone.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Connie Talbot - Never Give Up on Us (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Connie Talbot - Never Give Up on Us (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\david bowie - changes.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\david bowie - changes.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\David Guetta - Without You ft. Usher (Official Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\David Guetta - Without You ft. Usher (Official Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\David Wilcox Bad Apple.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\David Wilcox Bad Apple.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Dean Lewis - 7 Minutes (Official Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Dean Lewis - 7 Minutes (Official Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Destiny's Child - Survivor Lyrics.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Destiny's Child - Survivor Lyrics.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Disturbed - Down With The Sickness [Official Music Video].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Disturbed - Down With The Sickness [Official Music Video].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Disturbed - Who Taught You How To Hate [Official Audio].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Disturbed - Who Taught You How To Hate [Official Audio].mp3
# Non standard genre name: Unknown Genre
# Non standard genre name: Unknown Genre
# No tags found for C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Disturbed - Who Taught You How To Hate [Official Audio].mp3. Initializing tags.
# Tags initialized and saved.
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: Unknown Title
# Artist: Unknown Artist
# Album: Pre22March2025
# Genre: Unknown Genre
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Dolly Parton - Jolene (Official Audio).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Dolly Parton - Jolene (Official Audio).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\DontGo.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\DontGo.mp3
# Non standard genre name: Unknown Genre
# Non standard genre name: Unknown Genre
# No tags found for C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\DontGo.mp3. Initializing tags.
# Tags initialized and saved.
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: Unknown Title
# Artist: Unknown Artist
# Album: Pre22March2025
# Genre: Unknown Genre
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Dr. Dre - Fallin Up.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Dr. Dre - Fallin Up.mp3
# Failed to open C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Dr. Dre - Fallin Up.mp3: Failed to load the MP3 file: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Dr. Dre - Fallin Up.mp3
# Skipping C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Dr. Dre - Fallin Up.mp3 due to loading failure.
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Eclipse - _Viva La Victoria_ (Official Music Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Eclipse - _Viva La Victoria_ (Official Music Video).mp3
# Failed to open C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Eclipse - _Viva La Victoria_ (Official Music Video).mp3: Failed to load the MP3 file: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Eclipse - _Viva La Victoria_ (Official Music Video).mp3
# Skipping C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Eclipse - _Viva La Victoria_ (Official Music Video).mp3 due to loading failure.
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ed Sheeran - Beautiful People (Lyrics) FT. Khalid.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ed Sheeran - Beautiful People (Lyrics) FT. Khalid.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ed Sheeran - Castle On The Hill [Official Video].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ed Sheeran - Castle On The Hill [Official Video].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ed Sheeran - Don't (ExplicitSwearing).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ed Sheeran - Don't (ExplicitSwearing).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ed Sheeran - Lego House [LYRICS].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ed Sheeran - Lego House [LYRICS].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ed Sheeran - Remember The Name (feat. Eminem & 50 Cent) [Official Lyric Video].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ed Sheeran - Remember The Name (feat. Eminem & 50 Cent) [Official Lyric Video].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ed Sheeran, Camila Cabello - South of the Border (Lyrics) ft. Cardi B.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Ed Sheeran, Camila Cabello - South of the Border (Lyrics) ft. Cardi B.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
# Non standard genre name: Unknown Genre
# Non standard genre name: Unknown Genre
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Eleven Past One - The World Is Ours (Official Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Eleven Past One - The World Is Ours (Official Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Eminem - Godzilla (Lyrics) ft. Juice WRLD(2).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Eminem - Godzilla (Lyrics) ft. Juice WRLD(2).mp3
# No tags found for C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Eminem - Godzilla (Lyrics) ft. Juice WRLD(2).mp3. Initializing tags.
# Tags initialized and saved.
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: Unknown Title
# Artist: Unknown Artist
# Album: Pre22March2025
# Genre: Unknown Genre
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Eminem - Venom lyrics - ( official music video ).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Eminem - Venom lyrics - ( official music video ).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Eminem - W.T.P. Lyrics [HD].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Eminem - W.T.P. Lyrics [HD].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Eminem - [G.O.A.T].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Eminem - [G.O.A.T].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Emotional Oranges - West Coast Love (Audio).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Emotional Oranges - West Coast Love (Audio).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Evanescence - Bring Me To Life (Official Music Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Evanescence - Bring Me To Life (Official Music Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Evanescence - Going Under (Official Music Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Evanescence - Going Under (Official Music Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Every Breath You Take - The Police (Boyce Avenue acoustic cover) on Spotify & Apple.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Every Breath You Take - The Police (Boyce Avenue acoustic cover) on Spotify & Apple.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Everybody Loves Me.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Everybody Loves Me.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Everybody Talks - Neon Trees Lyrics.mp3
# ...
# Non standard genre name: Unknown Genre
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\VOLBEAT - Becoming (Official Music Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\VOLBEAT - Becoming (Official Music Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Wait A Minute My Girl.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Wait A Minute My Girl.mp3
# No tags found for C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Wait A Minute My Girl.mp3. Initializing tags.
# Non standard genre name: Unknown Genre
# Tags initialized and saved.
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: Unknown Title
# Artist: Unknown Artist
# Album: Pre22March2025
# Genre: Unknown Genre
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Welcome to the Fire - Willyecho (LYRICS).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Welcome to the Fire - Willyecho (LYRICS).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Where Did All The People Go.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Where Did All The People Go.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Whispers in the Dark.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Whispers in the Dark.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Wolves.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Wolves.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\X Ambassadors - Renegades (Lyric Video).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\X Ambassadors - Renegades (Lyric Video).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\X Ambassadors, Jamie N Commons - Jungle.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\X Ambassadors, Jamie N Commons - Jungle.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\y2mate.com - Lola Montez.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\y2mate.com - Lola Montez.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\y2mate.com - Volbeat  A Warriors Call Official Video.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\y2mate.com - Volbeat  A Warriors Call Official Video.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Break Stuff by Limp Bizkit Lyrics (Explicit)-3d9vrnptuF0-160k-1659344720660.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Break Stuff by Limp Bizkit Lyrics (Explicit)-3d9vrnptuF0-160k-1659344720660.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Disturbed - Indestructible [Official Music Video]-bK4UP0VyWZ8-160k-1655331673416.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Disturbed - Indestructible [Official Music Video]-bK4UP0VyWZ8-160k-1655331673416.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Inside the Fire - Disturbed Lyrics-ixjDcVhrbHQ-128k-1655356908103.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Inside the Fire - Disturbed Lyrics-ixjDcVhrbHQ-128k-1655356908103.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Kanye West - Jesus walks [HD]-y-aJLEaMCNw-160k-1655355796723.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Kanye West - Jesus walks [HD]-y-aJLEaMCNw-160k-1655355796723.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Nowhere Kids-6BkyuqaL8b0-160k-1655357023735.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Nowhere Kids-6BkyuqaL8b0-160k-1655357023735.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Ozzy Osbourne - Patient Number 9 (Official Music Video) ft. Jeff Beck-h_6DfxA6LiI-160k-1655264814806.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Ozzy Osbourne - Patient Number 9 (Official Music Video) ft. Jeff Beck-h_6DfxA6LiI-160k-1655264814806.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Paramore Misery Business [OFFICIAL VIDEO]-aCyGvGEtOwc-160k-1655094170848.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Paramore Misery Business [OFFICIAL VIDEO]-aCyGvGEtOwc-160k-1655094170848.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Sum 41 - In Too Deep (Official Music Video)-JoC3PUBmhFs-160k-1655339022416.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Sum 41 - In Too Deep (Official Music Video)-JoC3PUBmhFs-160k-1655339022416.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Sum 41 - Motivation (Official Music Video)-uXFqT-O9hbg-160k-1655356095878.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Sum 41 - Motivation (Official Music Video)-uXFqT-O9hbg-160k-1655356095878.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Sum 41 - The Hell Song-gjKQKnCUYkE-160k-1655357425152.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Sum 41 - The Hell Song-gjKQKnCUYkE-160k-1655357425152.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - The Offspring - Can't Repeat (Official Music Video)-sUtgowLdOEo-160k-1655364486595.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - The Offspring - Can't Repeat (Official Music Video)-sUtgowLdOEo-160k-1655364486595.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - The Offspring - The Kids Aren't Alright (Official Music Video)-7iNbnineUCI-160k-1654856630033.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - The Offspring - The Kids Aren't Alright (Official Music Video)-7iNbnineUCI-160k-1654856630033.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
# Invalid date: 0
# Invalid date: 0
# Non standard genre name: Unknown Genre
# Invalid date: 0
# Invalid date: 0
# Non standard genre name: Unknown Genre
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - The Offspring - This Is Not Utopia (Official Music Video)-4CI25W4BnYM-160k-1655355993360.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - The Offspring - This Is Not Utopia (Official Music Video)-4CI25W4BnYM-160k-1655355993360.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Three Days Grace - I Am The Weapon (Visualizer)-ZpqfAqDaGOA-160k-1655260261529.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Three Days Grace - I Am The Weapon (Visualizer)-ZpqfAqDaGOA-160k-1655260261529.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: I Am The Weapon
# Artist: Three Days Grace
# Album: Pre22March2025
# Genre: Unknown Genre
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Three Days Grace - Lifetime (Lyrics)-Z1dfObpKpE4-160k-1655357234627.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Three Days Grace - Lifetime (Lyrics)-Z1dfObpKpE4-160k-1655357234627.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: Lifetime
# Artist: Three Days Grace
# Album: Pre22March2025
# Genre: Unknown Genre
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Three Days Grace - Never Too Late-lL2ZwXj1tXM-160k-1658175868493.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Three Days Grace - Never Too Late-lL2ZwXj1tXM-160k-1658175868493.mp3
# Invalid date: 0
# Invalid date: 0
# Non standard genre name: Unknown Genre
# Invalid date: 0
# Invalid date: 0
# Non standard genre name: Unknown Genre
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: Never Too Late
# Artist: Three Days Grace
# Album: Pre22March2025
# Genre: Unknown Genre
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Three Days Grace - The Mountain (Official Video)-XblV5A1PlDo-160k-1655327985089.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Three Days Grace - The Mountain (Official Video)-XblV5A1PlDo-160k-1655327985089.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: The Mountain
# Artist: Three Days Grace
# Album: Pre22March2025
# Genre: Unknown Genre
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Volbeat - Still Counting-aXhjp85UNJI-160k-1655356351885.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - Volbeat - Still Counting-aXhjp85UNJI-160k-1655356351885.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - World so Cold-C_nqXvwOXaw-160k-1655356287490.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Y2Mate.is - World so Cold-C_nqXvwOXaw-160k-1655356287490.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\YNW Melly - Murder On My Mind (Lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\YNW Melly - Murder On My Mind (Lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\You Came to Party.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\You Came to Party.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Your Man by Josh Turner (with lyrics).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Your Man by Josh Turner (with lyrics).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Yung Gravy - Mr. Clean (prod. white shinobi) [Official Music Video].mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Yung Gravy - Mr. Clean (prod. white shinobi) [Official Music Video].mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Zac Brown Band - Colder Weather (Lyrics On Screen).mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Zac Brown Band - Colder Weather (Lyrics On Screen).mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
# Non standard genre name: Unknown Genre
# Non standard genre name: Unknown Genre
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\ZOMBIFIED.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\ZOMBIFIED.mp3
# No tags found for C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\ZOMBIFIED.mp3. Initializing tags.
# Tags initialized and saved.
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: Unknown Title
# Artist: Unknown Artist
# Album: Pre22March2025
# Genre: Unknown Genre
# --------------------------------------------------
# Processing: C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\[Lyric] Young Thug, 2 Chainz, Wiz Khalifa & PnB Rock Gang Up - BestOfLyrics.mp3
# C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\[Lyric] Young Thug, 2 Chainz, Wiz Khalifa & PnB Rock Gang Up - BestOfLyrics.mp3
# Current MP3 Tags:
#
# Updating MP3 Tags...
#
# Updated MP3 Tags:
# Title: None
# Artist: None
# Album: Pre22March2025
# Genre: None
# --------------------------------------------------

# %%
import eyed3

file_path = r"C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Adelitas Way - Invincible(lyrics) HQ.mp3"

# Try to load the file
audiofile = eyed3.load(file_path)

if audiofile is None:
    print("⚠️ eyed3 failed to load this file!")
else:
    print("✅ File loaded successfully!")

    # Check if the file has an ID3 tag
    if audiofile.tag is None:
        print("⚠️ No ID3 tags found. Trying to initialize...")
        audiofile.initTag()
        audiofile.tag.save()
        print("✅ ID3 tag initialized!")

    # Print metadata details
    print(f"Title: {audiofile.tag.title}")
    print(f"Artist: {audiofile.tag.artist}")
    print(f"Album: {audiofile.tag.album}")
    print(f"Genre: {audiofile.tag.genre}")

from mutagen.mp3 import MP3

try:
    audio = MP3(file_path)
    print("✅ Mutagen loaded the MP3 file successfully!")
    print(audio.info)
except Exception as e:
    print(f"❌ Mutagen also failed: {e}")

import magic

file_path = r"C:\WorkSpace\MP3Editor\files\musicOnPhone\Downloads\Adelitas Way - Invincible(lyrics) HQ.mp3"
mime = magic.Magic(mime=True)
print(mime.from_file(file_path))
# Out:
# ⚠️ eyed3 failed to load this file!
# ❌ Mutagen also failed: can't sync to MPEG frame
